# %%
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

# %%
avengers=pd.read_csv("avengers.csv")

# %%
avengers.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                 NaN                      Sep-63  1963                   52
# 1                 NaN                      Sep-63  1963                   52
# ...

# %% [markdown]
# Create a dataframe where Year >1959

# %%
true_av=avengers[avengers["Year"]>1959]
true_av.head()

# %% [markdown]
# Change all the "yes" values in the death1,death2,death3,death4,death5 columns to 1, "no" and nan to 0.

# %%
cols=["Death1","Death2","Death3","Death4","Death5"]
colmap={"YES":1,"NO":0,np.nan:0}
for c in cols:
    true_av[c]=true_av[c].map(colmap)
true_av.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# ...

# %% [markdown]
# Get the sum of deaths for each character in a new column called total_deaths.
# This represents the number of times the character died.

# %%
true_av["Total_deaths"]=true_av[cols].sum(axis=1)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
true_av
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5    http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6    http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7     http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8    http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9    http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10   http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11        http://marvel.wikia.com/Hercules_(Earth-616)
# 12      http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13          http://marvel.wikia.com/Vision_(Earth-616)
# 14                http://marvel.wikia.com/Dane_Whitman
# 15   http://marvel.wikia.com/Natalia_Romanova_(Eart...
# ...

# %% [markdown]
# which character died maximum times?

# %%
true_av[true_av["Total_deaths"]==5]
# Out:
#                                              URL Name/Alias  Appearances  \
# 32  http://marvel.wikia.com/Jocasta_(Earth-616)#    Jocasta          141
#
#    Current?  Gender Probationary Introl Full/Reserve Avengers Intro  Year  \
# 32      YES  FEMALE              Jul-80                      Nov-88  1988
#
#     Years since joining Honorary     ...       Death2 Return2  Death3 Return3  \
# 32                   27     Full     ...            1     YES       1     YES
#
#     Death4 Return4  Death5 Return5  \
# 32       1     YES       1     YES
#
#                                                 Notes Total_deaths
# 32  From her article: Death1: "Defeated Ultron and...            5
#
# [1 rows x 22 columns]

# %% [markdown]
# Calculate the number of rows where the years since joing has been correctly calculated for number of years since the charecter has been into existence until 2015.

# %%
true_av["correct_join"]=2015-true_av["Year"]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
true_av
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5    http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6    http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7     http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8    http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9    http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10   http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11        http://marvel.wikia.com/Hercules_(Earth-616)
# 12      http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13          http://marvel.wikia.com/Vision_(Earth-616)
# 14                http://marvel.wikia.com/Dane_Whitman
# 15   http://marvel.wikia.com/Natalia_Romanova_(Eart...
# ...

# %%
true_av=true_av[true_av["Years since joining"]==true_av["correct_join"]]

# %%
true_av.drop(["correct_join"],axis=1,inplace=True)

# %%
true_av.shape[0]
# Out:
# 159

# %%
true_av.columns
# Out:
# Index([u'URL', u'Name/Alias', u'Appearances', u'Current?', u'Gender',
#        u'Probationary Introl', u'Full/Reserve Avengers Intro', u'Year',
#        u'Years since joining', u'Honorary', u'Death1', u'Return1', u'Death2',
#        u'Return2', u'Death3', u'Return3', u'Death4', u'Return4', u'Death5',
#        u'Return5', u'Notes', u'Total_deaths'],
#       dtype='object')

# %%
returns_col=["Return1","Return2","Return3","Return4","Return5"]
for cols in returns_col:
    true_av[cols]=true_av[cols].map(col_map)
true_av
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5    http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6    http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7     http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8    http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9    http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 10   http://marvel.wikia.com/Jacques_Duquesne_(Eart...
# 11        http://marvel.wikia.com/Hercules_(Earth-616)
# 12      http://marvel.wikia.com/T%27Challa_(Earth-616)
# 13          http://marvel.wikia.com/Vision_(Earth-616)
# 14                http://marvel.wikia.com/Dane_Whitman
# 15   http://marvel.wikia.com/Natalia_Romanova_(Eart...
# ...

# %%
true_av["Total_retuns"]=true_av[returns_col].sum(axis=1)

# %%
true_av[true_av["Total_retuns"]==true_av["Total_retuns"].max()]
# Out:
#                                              URL Name/Alias  Appearances  \
# 32  http://marvel.wikia.com/Jocasta_(Earth-616)#    Jocasta          141
#
#    Current?  Gender Probationary Introl Full/Reserve Avengers Intro  Year  \
# 32      YES  FEMALE              Jul-80                      Nov-88  1988
#
#     Years since joining Honorary     ...       Return2 Death3  Return3 Death4  \
# 32                   27     Full     ...          True      1     True      1
#
#     Return4 Death5  Return5  \
# 32     True      1     True
#
#                                                 Notes  Total_deaths  \
# 32  From her article: Death1: "Defeated Ultron and...             5
#
#    Total_retuns
# 32            5
#
# [1 rows x 23 columns]

# %% [markdown]
# which character/s seemd to be most popular by way of being there max number of years and having max appearances

# %%
abc=true_av[true_av["Years since joining"]==true_av["Years since joining"].max()]

# %%
abc[abc["Appearances"]==abc["Appearances"].max()]
# Out:
#                                                  URL  \
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
#
#                     Name/Alias  Appearances Current? Gender  \
# 2  Anthony Edward "Tony" Stark         3068      YES   MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 2                 NaN                      Sep-63  1963                   52
#
#   Honorary     ...       Return2 Death3  Return3 Death4  Return4 Death5  \
# 2     Full     ...         False      0    False      0    False      0
#
#    Return5                                              Notes  Total_deaths  \
# 2    False  Death: "Later while under the influence of Imm...             1
#
#   Total_retuns
# 2            1
#
# [1 rows x 23 columns]
